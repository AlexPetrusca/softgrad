# %%
# train the model

import os
import sys

import numpy as np
import mlx.core as mx
import mlx.nn as nn
import matplotlib.pyplot as plt
from PIL import Image

from softgrad import Network
from softgrad.layer.transform import Flatten, Reshape, Transpose
from softgrad.layer.shim import MLX
from softgrad.optim import SGD
from softgrad.function.activation import leaky_relu, softmax, relu
from softgrad.function.loss import CrossEntropyLoss, cross_entropy_loss
from softgrad.layer.core import Linear, Activation

sys.path.append(os.path.abspath('..'))
from util.dataset import get_mnist, get_fashion_mnist, get_cifar10


# Visualize
def viz_sample_predictions(network, test_data, label_map, rows=5, cols=5, figsize=(10, 10)):
    fig, axes = plt.subplots(rows, cols, figsize=figsize, num="Sample Predictions")
    axes = axes.reshape(-1)  # flatten

    test_data = test_data.to_buffer().shuffle()
    def sample_random():
        for j in np.arange(0, rows * cols):
            i = np.random.randint(0, len(test_data))
            x = mx.array(test_data[i]['image'])
            y = mx.array(test_data[i]['label'])
            y_pred = network.forward(x[mx.newaxis, ...])

            sample = np.array(255 * x)
            if sample.shape[2] == 3:
                image = Image.fromarray(sample.astype('uint8'))
            else:
                image = Image.fromarray(sample.reshape(sample.shape[0], sample.shape[1]))

            raw_label = mx.argmax(y).item()
            label = label_map[raw_label]

            raw_pred = mx.argmax(y_pred).item()
            pred = label_map[raw_pred]

            axes[j].imshow(image)
            axes[j].set_title(f"True: {label} \nPredict: {pred}")
            axes[j].axis('off')
            plt.subplots_adjust(wspace=1)

    def on_key(event):
        if event.key == ' ':
            sample_random()
            fig.show()

    fig.canvas.mpl_connect('key_press_event', on_key)

    sample_random()


def viz_history(history, figsize=(6, 4)):
    plt.figure(figsize=figsize, num="Loss Curves")
    plt.plot(history['epoch'], history['train_loss'], 'black', linewidth=2.0)
    plt.plot(history['epoch'], history['test_loss'], 'green', linewidth=2.0)
    plt.legend(['Training Loss', 'Validation Loss'], fontsize=14)
    plt.xlabel('Epochs', fontsize=10)
    plt.ylabel('Loss', fontsize=10)
    plt.title('Loss vs Epoch', fontsize=12)

    plt.figure(figsize=figsize, num="Accuracy Curves")
    plt.plot(history['epoch'], history['train_accuracy'], 'black', linewidth=2.0)
    plt.plot(history['epoch'], history['test_accuracy'], 'green', linewidth=2.0)
    plt.legend(['Training Accuracy', 'Validation Accuracy'], fontsize=14)
    plt.xlabel('Epochs', fontsize=10)
    plt.ylabel('Accuracy', fontsize=10)
    plt.title('Accuracy vs Epoch', fontsize=12)


# Evaluate
def eval_model(model, dataset, epoch=None):
    mean_losses = []
    accuracies = []
    predictions = []

    for batch in dataset:
        x_batch = mx.array(batch["image"])
        y_batch = mx.array(batch["label"])

        y_pred = model.forward(x_batch)
        predictions.append(y_pred)

        loss = optimizer.loss_fn(y_pred, y_batch)
        mean_loss = mx.mean(mx.sum(loss, axis=1))
        mean_losses.append(mean_loss.item())

        if isinstance(optimizer.loss_fn, CrossEntropyLoss):
            y_pred = softmax(y_pred)

        errors = mx.sum(mx.abs(y_batch - mx.round(y_pred)), axis=1)
        accuracy = mx.sum(errors == 0) / y_batch.shape[0]
        accuracies.append(accuracy.item())

    mean_loss = sum(mean_losses) / len(mean_losses)
    accuracy = sum(accuracies) / len(accuracies)
    predictions = np.concatenate(predictions)

    dataset.reset()

    if epoch is not None:
        print(f"Epoch {epoch}: Accuracy {accuracy:.3f}, Average Loss {mean_loss}")
    else:
        print(f"Accuracy {accuracy:.3f}, Average Loss {mean_loss}")

    return predictions, accuracy, mean_loss


def train(train_data, epochs, batch_size=1, test_data=None, cb=None):
    batched_train_data = train_data.batch(batch_size)
    batched_test_data = test_data.batch(batch_size)

    def train_epoch():
        for batch in batched_train_data:
            x_batch = mx.array(batch["image"])
            y_batch = mx.array(batch["label"])
            optimizer.step(x_batch, y_batch)
        batched_train_data.reset()

    history = {"epoch": [], "train_loss": [], "test_loss": [], "train_accuracy": [], "test_accuracy": []}

    _, train_accuracy, train_loss = eval_model(network, batched_train_data, epoch=0)
    _, test_accuracy, test_loss = eval_model(network, batched_test_data, epoch=0)
    print()
    history["epoch"].append(0)
    history["train_loss"].append(train_loss)
    history["test_loss"].append(test_loss)
    history["train_accuracy"].append(train_accuracy)
    history["test_accuracy"].append(test_accuracy)

    for epoch in range(1, epochs + 1):
        train_epoch()

        _, train_accuracy, train_loss = eval_model(network, batched_train_data, epoch=epoch)
        _, test_accuracy, test_loss = eval_model(network, batched_test_data, epoch=epoch)
        print()
        history["epoch"].append(epoch)
        history["train_loss"].append(train_loss)
        history["test_loss"].append(test_loss)
        history["train_accuracy"].append(train_accuracy)
        history["test_accuracy"].append(test_accuracy)

    test_data.reset()
    eval_model(network, batched_test_data)
    print()

    viz_sample_predictions(network, test_data, label_map)
    viz_history(history)
    plt.show()


# train_data, test_data = get_mnist(static=False)
# label_map = ["Zero", "One", "Two", "Three", "Four", "Five", "Six", "Seven", "Eight", "Nine"]

train_data, test_data = get_fashion_mnist(static=False)
label_map = ["T-shirt/top", "Trouser", "Pullover", "Dress", "Coat", "Sandal", "Shirt", "Sneaker", "Bag", "Ankle boot"]

# train_data, test_data = get_cifar10(static=False)
# label_map = ["Airplane", "Automobile", "Bird", "Cat", "Deer", "Dog", "Frog", "Horse", "Ship", "Truck"]

network = Network(input_shape=(32, 32, 1))

# conv block 1
network.add_layer(MLX(nn.Conv2d(in_channels=1, out_channels=96, kernel_size=7)))
network.add_layer(Activation(leaky_relu))
network.add_layer(MLX(nn.MaxPool2d(2)))
# conv block 2
network.add_layer(MLX(nn.Conv2d(in_channels=96, out_channels=256, kernel_size=3)))
network.add_layer(Activation(leaky_relu))
network.add_layer(MLX(nn.MaxPool2d(2)))
# feed forward
network.add_layer(Flatten())
network.add_layer(Linear(1024))
network.add_layer(Activation(leaky_relu))
network.add_layer(Linear(10))

optimizer = SGD(eta=0.05, momentum=0.9, weight_decay=0.0005)
optimizer.bind_loss_fn(cross_entropy_loss)
optimizer.bind_network(network)

train(train_data, epochs=100, batch_size=1000, test_data=test_data)
# Out:
# Epoch 0: Accuracy 0.000, Average Loss 2.302501940727234
# Epoch 0: Accuracy 0.000, Average Loss 2.3022523403167723
#
# Epoch 1: Accuracy 0.597, Average Loss 0.751913559436798
# Epoch 1: Accuracy 0.618, Average Loss 0.7258203029632568
#
# Epoch 2: Accuracy 0.711, Average Loss 0.5501665726304055
# Epoch 2: Accuracy 0.733, Average Loss 0.5230950295925141
#
# Epoch 3: Accuracy 0.760, Average Loss 0.4806077529986699
# Epoch 3: Accuracy 0.782, Average Loss 0.4583264887332916
#
# Epoch 4: Accuracy 0.805, Average Loss 0.42426507075627645
# Epoch 4: Accuracy 0.821, Average Loss 0.4047160536050797
#
# Epoch 5: Accuracy 0.824, Average Loss 0.3933457836508751
# Epoch 5: Accuracy 0.839, Average Loss 0.37725446224212644
#
# Epoch 6: Accuracy 0.833, Average Loss 0.3735723108053207
# Epoch 6: Accuracy 0.845, Average Loss 0.3588666975498199
#
# Epoch 7: Accuracy 0.840, Average Loss 0.35943508297204974
# Epoch 7: Accuracy 0.854, Average Loss 0.34137182533740995
#
# Epoch 8: Accuracy 0.856, Average Loss 0.32940838287274044
# Epoch 8: Accuracy 0.863, Average Loss 0.3239287704229355
#
# Epoch 9: Accuracy 0.863, Average Loss 0.32210451712210975
# Epoch 9: Accuracy 0.868, Average Loss 0.31783064007759093
#
# Epoch 10: Accuracy 0.870, Average Loss 0.30203578174114226
# Epoch 10: Accuracy 0.876, Average Loss 0.29899172484874725
#
# Epoch 11: Accuracy 0.874, Average Loss 0.2955352405707041
# Epoch 11: Accuracy 0.879, Average Loss 0.2932237029075623
#
# Epoch 12: Accuracy 0.877, Average Loss 0.28605911458532013
# Epoch 12: Accuracy 0.881, Average Loss 0.2909366965293884
#
# Epoch 13: Accuracy 0.884, Average Loss 0.2748249543209871
# Epoch 13: Accuracy 0.885, Average Loss 0.28129613399505615
#
# Epoch 14: Accuracy 0.881, Average Loss 0.27834009379148483
# Epoch 14: Accuracy 0.884, Average Loss 0.2822724789381027
#
# Epoch 15: Accuracy 0.877, Average Loss 0.2866642008225123
# Epoch 15: Accuracy 0.881, Average Loss 0.29223300516605377
#
# Epoch 16: Accuracy 0.887, Average Loss 0.26403073271115624
# Epoch 16: Accuracy 0.890, Average Loss 0.26986092776060105
#
# Epoch 17: Accuracy 0.890, Average Loss 0.2604447233180205
# Epoch 17: Accuracy 0.890, Average Loss 0.27215818166732786
#
# Epoch 18: Accuracy 0.891, Average Loss 0.25717411587635675
# Epoch 18: Accuracy 0.890, Average Loss 0.26994927078485487
#
# Epoch 19: Accuracy 0.892, Average Loss 0.25396283268928527
# Epoch 19: Accuracy 0.892, Average Loss 0.26821664422750474
#
# Epoch 20: Accuracy 0.899, Average Loss 0.24134500722090405
# Epoch 20: Accuracy 0.900, Average Loss 0.2572621017694473
#
# Epoch 21: Accuracy 0.901, Average Loss 0.23668582861622176
# Epoch 21: Accuracy 0.899, Average Loss 0.2571984976530075
#
# Epoch 22: Accuracy 0.905, Average Loss 0.22371678923567137
# Epoch 22: Accuracy 0.902, Average Loss 0.24734147489070893
#
# Epoch 23: Accuracy 0.901, Average Loss 0.23389962290724117
# Epoch 23: Accuracy 0.898, Average Loss 0.2602947801351547
#
# Epoch 24: Accuracy 0.903, Average Loss 0.22927413508296013
# Epoch 24: Accuracy 0.900, Average Loss 0.24972976446151735
#
# Epoch 25: Accuracy 0.911, Average Loss 0.21532111689448358
# Epoch 25: Accuracy 0.907, Average Loss 0.2416168212890625
#
# Epoch 26: Accuracy 0.910, Average Loss 0.21565793976187705
# Epoch 26: Accuracy 0.905, Average Loss 0.24187453836202621
#
# Epoch 27: Accuracy 0.909, Average Loss 0.2198704292376836
# Epoch 27: Accuracy 0.906, Average Loss 0.24706000387668609
#
# Epoch 28: Accuracy 0.916, Average Loss 0.20288409516215325
# Epoch 28: Accuracy 0.908, Average Loss 0.2348428413271904
#
# Epoch 29: Accuracy 0.912, Average Loss 0.21134606252113977
# Epoch 29: Accuracy 0.905, Average Loss 0.24373447000980378
#
# Epoch 30: Accuracy 0.916, Average Loss 0.1990284872551759
# Epoch 30: Accuracy 0.908, Average Loss 0.23506730943918228
#
# Epoch 31: Accuracy 0.919, Average Loss 0.19644720007975897
# Epoch 31: Accuracy 0.911, Average Loss 0.2301736816763878
#
# Epoch 32: Accuracy 0.917, Average Loss 0.20341122249762217
# Epoch 32: Accuracy 0.908, Average Loss 0.24124093651771544
#
# Epoch 33: Accuracy 0.918, Average Loss 0.19812245791157088
# Epoch 33: Accuracy 0.907, Average Loss 0.24113181978464127
#
# Epoch 34: Accuracy 0.922, Average Loss 0.18937550534804662
# Epoch 34: Accuracy 0.911, Average Loss 0.22653097659349442
#
# Epoch 35: Accuracy 0.920, Average Loss 0.1917454389234384
# Epoch 35: Accuracy 0.912, Average Loss 0.22931253165006638
#
# Epoch 36: Accuracy 0.924, Average Loss 0.1832148720820745
# Epoch 36: Accuracy 0.910, Average Loss 0.2277581810951233
#
# Epoch 37: Accuracy 0.922, Average Loss 0.18749385997653006
# Epoch 37: Accuracy 0.911, Average Loss 0.2307902067899704
#
# Epoch 38: Accuracy 0.926, Average Loss 0.17859846875071525
# Epoch 38: Accuracy 0.914, Average Loss 0.22664792835712433
#
# Epoch 39: Accuracy 0.928, Average Loss 0.17480942780772846
# Epoch 39: Accuracy 0.912, Average Loss 0.22591557800769807
#
# Epoch 40: Accuracy 0.928, Average Loss 0.17538515627384185
# Epoch 40: Accuracy 0.910, Average Loss 0.22648297548294066
#
# Epoch 41: Accuracy 0.926, Average Loss 0.1780894286930561
# Epoch 41: Accuracy 0.912, Average Loss 0.22958333641290665
#
# Epoch 42: Accuracy 0.927, Average Loss 0.17438646430770557
# Epoch 42: Accuracy 0.914, Average Loss 0.21965234130620956
#
# Epoch 43: Accuracy 0.930, Average Loss 0.16960622866948447
# Epoch 43: Accuracy 0.916, Average Loss 0.2226617306470871
#
# Epoch 44: Accuracy 0.931, Average Loss 0.166804322352012
# Epoch 44: Accuracy 0.914, Average Loss 0.22233155518770217
#
# Epoch 45: Accuracy 0.931, Average Loss 0.16865258564551672
# Epoch 45: Accuracy 0.914, Average Loss 0.22387811541557312
#
# Epoch 46: Accuracy 0.934, Average Loss 0.16039474147061508
# Epoch 46: Accuracy 0.916, Average Loss 0.21784328818321227
#
# Epoch 47: Accuracy 0.935, Average Loss 0.15812685415148736
# Epoch 47: Accuracy 0.918, Average Loss 0.2175253376364708
#
# Epoch 48: Accuracy 0.936, Average Loss 0.1562150185306867
# Epoch 48: Accuracy 0.917, Average Loss 0.22077759951353074
#
# Epoch 49: Accuracy 0.934, Average Loss 0.15868838590880235
# Epoch 49: Accuracy 0.916, Average Loss 0.2208888366818428
#
# Epoch 50: Accuracy 0.931, Average Loss 0.16672713880737622
# Epoch 50: Accuracy 0.913, Average Loss 0.23536201268434526
#
# Epoch 51: Accuracy 0.936, Average Loss 0.1569034904241562
# Epoch 51: Accuracy 0.915, Average Loss 0.22682258486747742
#
# Epoch 52: Accuracy 0.936, Average Loss 0.1574251875281334
# Epoch 52: Accuracy 0.918, Average Loss 0.2262539952993393
#
# Epoch 53: Accuracy 0.936, Average Loss 0.15483346271018186
# Epoch 53: Accuracy 0.917, Average Loss 0.2254180058836937
#
# Epoch 54: Accuracy 0.938, Average Loss 0.15036747480432192
# Epoch 54: Accuracy 0.917, Average Loss 0.2231363460421562
#
# Epoch 55: Accuracy 0.939, Average Loss 0.1508786643544833
# Epoch 55: Accuracy 0.916, Average Loss 0.2228514537215233
#
# Epoch 56: Accuracy 0.943, Average Loss 0.1407994106411934
# Epoch 56: Accuracy 0.921, Average Loss 0.21500191539525987
#
# Epoch 57: Accuracy 0.942, Average Loss 0.14290043028692404
# Epoch 57: Accuracy 0.921, Average Loss 0.2197159931063652
#
# Epoch 58: Accuracy 0.942, Average Loss 0.142499778047204
# Epoch 58: Accuracy 0.922, Average Loss 0.21352352797985077
#
# Epoch 59: Accuracy 0.945, Average Loss 0.13549056947231292
# Epoch 59: Accuracy 0.923, Average Loss 0.21313053816556932
#
# Epoch 60: Accuracy 0.945, Average Loss 0.1342651082823674
# Epoch 60: Accuracy 0.923, Average Loss 0.213920958340168
#
# Epoch 61: Accuracy 0.944, Average Loss 0.13670884259045124
# Epoch 61: Accuracy 0.921, Average Loss 0.2154697448015213
#
# Epoch 62: Accuracy 0.943, Average Loss 0.1388669978827238
# Epoch 62: Accuracy 0.920, Average Loss 0.21948661804199218
#
# Epoch 63: Accuracy 0.945, Average Loss 0.13263020428518454
# Epoch 63: Accuracy 0.921, Average Loss 0.2180650532245636
#
# Epoch 64: Accuracy 0.944, Average Loss 0.13961276486516
# Epoch 64: Accuracy 0.922, Average Loss 0.22349510192871094
#
# Epoch 65: Accuracy 0.945, Average Loss 0.1345102943480015
# Epoch 65: Accuracy 0.923, Average Loss 0.2178288996219635
#
# Epoch 66: Accuracy 0.946, Average Loss 0.13389673146108785
# Epoch 66: Accuracy 0.920, Average Loss 0.22525152564048767
#
# Epoch 67: Accuracy 0.950, Average Loss 0.12568366155028343
# Epoch 67: Accuracy 0.925, Average Loss 0.21413649320602418
#
# Epoch 68: Accuracy 0.946, Average Loss 0.13124599494040012
# Epoch 68: Accuracy 0.922, Average Loss 0.21993347704410554
#
# Epoch 69: Accuracy 0.949, Average Loss 0.12711139445503553
# Epoch 69: Accuracy 0.921, Average Loss 0.22488459944725037
#
# Epoch 70: Accuracy 0.952, Average Loss 0.11990080513060093
# Epoch 70: Accuracy 0.923, Average Loss 0.219667749106884
#
# Epoch 71: Accuracy 0.949, Average Loss 0.12530016961197057
# Epoch 71: Accuracy 0.922, Average Loss 0.22438392788171768
#
# Epoch 72: Accuracy 0.953, Average Loss 0.11771687443057696
# Epoch 72: Accuracy 0.924, Average Loss 0.21877144724130632
#
# Epoch 73: Accuracy 0.953, Average Loss 0.11649142615497113
# Epoch 73: Accuracy 0.924, Average Loss 0.2202363356947899
#
# Epoch 74: Accuracy 0.951, Average Loss 0.12259331954022248
# Epoch 74: Accuracy 0.920, Average Loss 0.22474943995475768
#
# Epoch 75: Accuracy 0.952, Average Loss 0.11739186470707258
# Epoch 75: Accuracy 0.924, Average Loss 0.22096094638109207
#
# Epoch 76: Accuracy 0.953, Average Loss 0.11456778397162755
# Epoch 76: Accuracy 0.923, Average Loss 0.22041917592287064
#
# Epoch 77: Accuracy 0.953, Average Loss 0.11530706882476807
# Epoch 77: Accuracy 0.923, Average Loss 0.21585938036441804
#
# Epoch 78: Accuracy 0.953, Average Loss 0.11325810874501864
# Epoch 78: Accuracy 0.925, Average Loss 0.21718818098306655
#
# Epoch 79: Accuracy 0.955, Average Loss 0.11081284048656623
# Epoch 79: Accuracy 0.923, Average Loss 0.21513959318399428
#
# Epoch 80: Accuracy 0.956, Average Loss 0.10897529659171899
# Epoch 80: Accuracy 0.924, Average Loss 0.22557393908500672
#
# Epoch 81: Accuracy 0.954, Average Loss 0.11235252656042576
# Epoch 81: Accuracy 0.923, Average Loss 0.22475942969322205
#
# Epoch 82: Accuracy 0.955, Average Loss 0.10942279112835725
# Epoch 82: Accuracy 0.921, Average Loss 0.22761647552251815
#
# Epoch 83: Accuracy 0.956, Average Loss 0.11008983167509238
# Epoch 83: Accuracy 0.925, Average Loss 0.22862838357686996
#
# Epoch 84: Accuracy 0.956, Average Loss 0.10854825240870317
# Epoch 84: Accuracy 0.925, Average Loss 0.23064881116151809
#
# Epoch 85: Accuracy 0.958, Average Loss 0.10383419891198477
# Epoch 85: Accuracy 0.927, Average Loss 0.22256250232458114
#
# Epoch 86: Accuracy 0.957, Average Loss 0.10407821871340275
# Epoch 86: Accuracy 0.925, Average Loss 0.22333235293626785
#
# Epoch 87: Accuracy 0.959, Average Loss 0.10291629234949748
# Epoch 87: Accuracy 0.923, Average Loss 0.23256583362817765
#
# Epoch 88: Accuracy 0.964, Average Loss 0.09148778772602478
# Epoch 88: Accuracy 0.928, Average Loss 0.22422146499156953
#
# Epoch 89: Accuracy 0.962, Average Loss 0.09597682108481725
# Epoch 89: Accuracy 0.927, Average Loss 0.2291802480816841
#
# Epoch 90: Accuracy 0.961, Average Loss 0.10051543277998766
# Epoch 90: Accuracy 0.922, Average Loss 0.2371581271290779
#
# Epoch 91: Accuracy 0.963, Average Loss 0.09186728398005167
# Epoch 91: Accuracy 0.929, Average Loss 0.2284466177225113
#
# Epoch 92: Accuracy 0.960, Average Loss 0.0988349242756764
# Epoch 92: Accuracy 0.926, Average Loss 0.23844162076711656
#
# Epoch 93: Accuracy 0.960, Average Loss 0.1009327674905459
# Epoch 93: Accuracy 0.928, Average Loss 0.235487000644207
#
# Epoch 94: Accuracy 0.962, Average Loss 0.0933528333902359
# Epoch 94: Accuracy 0.930, Average Loss 0.2344820097088814
#
# Epoch 95: Accuracy 0.960, Average Loss 0.1016461819410324
# Epoch 95: Accuracy 0.925, Average Loss 0.25112874507904054
#
# Epoch 96: Accuracy 0.961, Average Loss 0.0969084445387125
# Epoch 96: Accuracy 0.925, Average Loss 0.24673064798116684
#
# Epoch 97: Accuracy 0.963, Average Loss 0.09221201837062835
# Epoch 97: Accuracy 0.927, Average Loss 0.23592429161071776
#
# Epoch 98: Accuracy 0.965, Average Loss 0.08796809508154789
# Epoch 98: Accuracy 0.930, Average Loss 0.23100967109203338
#
# Epoch 99: Accuracy 0.962, Average Loss 0.09098980662723383
# Epoch 99: Accuracy 0.927, Average Loss 0.24080357253551482
#
# Epoch 100: Accuracy 0.968, Average Loss 0.08085016682744026
# Epoch 100: Accuracy 0.929, Average Loss 0.23476434201002122
#
# Accuracy 0.929, Average Loss 0.23476434201002122

# %%
kernels = network.layers[0].params['weight']
kernel = np.array(kernels[50])
print("Kernel Shape:", kernels.shape)
print("Example:", kernel)

def normalize(kernel):
    kernel -= np.min(kernel)
    kernel /= np.max(kernel)
    return 255 * kernel.reshape(kernel.shape[0], kernel.shape[1])

kernel_img = Image.fromarray(normalize(kernel))
plt.imshow(kernel_img)
# Out:
# Kernel Shape: (96, 7, 7, 1)
# Example: [[[-0.0621038 ]
#   [-0.05618278]
#   [ 0.032008  ]
#   [-0.10205255]
#   [-0.08068708]
#   [-0.01964189]
#   [-0.04744719]]
#
#  [[ 0.04903335]
#   [ 0.10061606]
#   [ 0.04289756]
#   [-0.06721462]
#   [ 0.08607734]
#   [ 0.0262669 ]
#   [-0.07329471]]
#
#  [[ 0.09677433]
#   [ 0.02022723]
#   [-0.15115394]
#   [ 0.07552736]
#   [ 0.08967626]
#   [-0.15553416]
#   [-0.13042624]]
#
#  [[ 0.05858276]
#   [-0.16139527]
#   [-0.1482589 ]
#   [-0.01561882]
#   [-0.03719785]
#   [-0.17282335]
#   [-0.07704824]]
#
#  [[ 0.07513332]
#   [-0.17439902]
#   [-0.02083489]
#   [ 0.07826481]
#   [-0.09515866]
#   [ 0.08208986]
#   [-0.0287959 ]]
#
#  [[-0.03695035]
#   [-0.06911578]
#   [-0.08329036]
#   [-0.0625481 ]
#   [-0.03644834]
#   [ 0.08727624]
#   [ 0.01662575]]
#
#  [[-0.1899745 ]
#   [ 0.04429918]
#   [-0.05740265]
#   [-0.14749321]
#   [ 0.04723581]
#   [-0.14555286]
#   [-0.04811654]]]

# %%
def viz_kernels(kernels, rows=24, cols=4, figsize=(10, 60)):
    fig, axes = plt.subplots(rows, cols, figsize=figsize, num="Sample Predictions")
    axes = axes.reshape(-1)  # flatten

    def normalize_kernels(kernels):
        kernels = np.array(kernels.reshape(kernels.shape[0], kernels.shape[1], kernels.shape[2]))

        kernels = kernels - np.min(kernels)
        kernels = kernels / np.max(kernels)
        kernels = np.square(kernels)

        print("Mins", np.min(kernels))
        print("Maxs", np.max(kernels))

        return kernels

    kernels = normalize_kernels(kernels)

    def normalize(kernel):
        return 255 * kernel

    def imagize(kernel):
        return Image.fromarray(normalize(kernel))

    for j, kernel in enumerate(kernels):
        kernel_img = imagize(kernel)
        axes[j].imshow(kernel_img)
        axes[j].set_title(f"Kernel {j}")
        axes[j].axis('off')
        plt.subplots_adjust(wspace=1)

    plt.show()

viz_kernels(network.layers[0].params['weight'])
# Out:
# Mins 0.0
# Maxs 1.0
