# %%
# train the model

import os
import sys

import numpy as np
import mlx.core as mx
import mlx.nn as nn
import matplotlib.pyplot as plt
from PIL import Image

from softgrad import Network
from softgrad.layer.transform import Flatten, Reshape, Transpose
from softgrad.layer.shim import MLX
from softgrad.optim import SGD
from softgrad.function.activation import leaky_relu, softmax, relu
from softgrad.function.loss import CrossEntropyLoss, cross_entropy_loss
from softgrad.layer.core import Linear, Activation

sys.path.append(os.path.abspath('..'))
from util.dataset import get_mnist, get_fashion_mnist, get_cifar10


# Visualize
def viz_sample_predictions(network, test_data, label_map, rows=5, cols=5, figsize=(10, 10)):
    fig, axes = plt.subplots(rows, cols, figsize=figsize, num="Sample Predictions")
    axes = axes.reshape(-1)  # flatten

    test_data = test_data.to_buffer().shuffle()
    def sample_random():
        for j in np.arange(0, rows * cols):
            i = np.random.randint(0, len(test_data))
            x = mx.array(test_data[i]['image'])
            y = mx.array(test_data[i]['label'])
            y_pred = network.forward(x[mx.newaxis, ...])

            sample = np.array(255 * x)
            if sample.shape[2] == 3:
                image = Image.fromarray(sample.astype('uint8'))
            else:
                image = Image.fromarray(sample.reshape(sample.shape[0], sample.shape[1]))

            raw_label = mx.argmax(y).item()
            label = label_map[raw_label]

            raw_pred = mx.argmax(y_pred).item()
            pred = label_map[raw_pred]

            axes[j].imshow(image)
            axes[j].set_title(f"True: {label} \nPredict: {pred}")
            axes[j].axis('off')
            plt.subplots_adjust(wspace=1)

    def on_key(event):
        if event.key == ' ':
            sample_random()
            fig.show()

    fig.canvas.mpl_connect('key_press_event', on_key)

    sample_random()


def viz_history(history, figsize=(6, 4)):
    plt.figure(figsize=figsize, num="Loss Curves")
    plt.plot(history['epoch'], history['train_loss'], 'black', linewidth=2.0)
    plt.plot(history['epoch'], history['test_loss'], 'green', linewidth=2.0)
    plt.legend(['Training Loss', 'Validation Loss'], fontsize=14)
    plt.xlabel('Epochs', fontsize=10)
    plt.ylabel('Loss', fontsize=10)
    plt.title('Loss vs Epoch', fontsize=12)

    plt.figure(figsize=figsize, num="Accuracy Curves")
    plt.plot(history['epoch'], history['train_accuracy'], 'black', linewidth=2.0)
    plt.plot(history['epoch'], history['test_accuracy'], 'green', linewidth=2.0)
    plt.legend(['Training Accuracy', 'Validation Accuracy'], fontsize=14)
    plt.xlabel('Epochs', fontsize=10)
    plt.ylabel('Accuracy', fontsize=10)
    plt.title('Accuracy vs Epoch', fontsize=12)


# Evaluate
def eval_model(model, dataset, epoch=None):
    mean_losses = []
    accuracies = []
    predictions = []

    for batch in dataset:
        x_batch = mx.array(batch["image"])
        y_batch = mx.array(batch["label"])

        y_pred = model.forward(x_batch)
        predictions.append(y_pred)

        loss = optimizer.loss_fn(y_pred, y_batch)
        mean_loss = mx.mean(mx.sum(loss, axis=1))
        mean_losses.append(mean_loss.item())

        if isinstance(optimizer.loss_fn, CrossEntropyLoss):
            y_pred = softmax(y_pred)

        errors = mx.sum(mx.abs(y_batch - mx.round(y_pred)), axis=1)
        accuracy = mx.sum(errors == 0) / y_batch.shape[0]
        accuracies.append(accuracy.item())

    mean_loss = sum(mean_losses) / len(mean_losses)
    accuracy = sum(accuracies) / len(accuracies)
    predictions = np.concatenate(predictions)

    dataset.reset()

    if epoch is not None:
        print(f"Epoch {epoch}: Accuracy {accuracy:.3f}, Average Loss {mean_loss}")
    else:
        print(f"Accuracy {accuracy:.3f}, Average Loss {mean_loss}")

    return predictions, accuracy, mean_loss


def train(train_data, epochs, batch_size=1, test_data=None, cb=None):
    batched_train_data = train_data.batch(batch_size)
    batched_test_data = test_data.batch(batch_size)

    def train_epoch():
        for batch in batched_train_data:
            x_batch = mx.array(batch["image"])
            y_batch = mx.array(batch["label"])
            optimizer.step(x_batch, y_batch)
        batched_train_data.reset()

    history = {"epoch": [], "train_loss": [], "test_loss": [], "train_accuracy": [], "test_accuracy": []}

    _, train_accuracy, train_loss = eval_model(network, batched_train_data, epoch=0)
    _, test_accuracy, test_loss = eval_model(network, batched_test_data, epoch=0)
    print()
    history["epoch"].append(0)
    history["train_loss"].append(train_loss)
    history["test_loss"].append(test_loss)
    history["train_accuracy"].append(train_accuracy)
    history["test_accuracy"].append(test_accuracy)

    for epoch in range(1, epochs + 1):
        train_epoch()

        _, train_accuracy, train_loss = eval_model(network, batched_train_data, epoch=epoch)
        _, test_accuracy, test_loss = eval_model(network, batched_test_data, epoch=epoch)
        print()
        history["epoch"].append(epoch)
        history["train_loss"].append(train_loss)
        history["test_loss"].append(test_loss)
        history["train_accuracy"].append(train_accuracy)
        history["test_accuracy"].append(test_accuracy)

    test_data.reset()
    eval_model(network, batched_test_data)
    print()

    viz_sample_predictions(network, test_data, label_map)
    viz_history(history)
    plt.show()


train_data, test_data = get_mnist(static=False)
label_map = ["Zero", "One", "Two", "Three", "Four", "Five", "Six", "Seven", "Eight", "Nine"]

# train_data, test_data = get_fashion_mnist(static=False)
# label_map = ["T-shirt/top", "Trouser", "Pullover", "Dress", "Coat", "Sandal", "Shirt", "Sneaker", "Bag", "Ankle boot"]

# train_data, test_data = get_cifar10(static=False)
# label_map = ["Airplane", "Automobile", "Bird", "Cat", "Deer", "Dog", "Frog", "Horse", "Ship", "Truck"]

network = Network(input_shape=(32, 32, 1))

# conv block 1
network.add_layer(MLX(nn.Conv2d(in_channels=1, out_channels=96, kernel_size=7)))
network.add_layer(Activation(leaky_relu))
network.add_layer(MLX(nn.MaxPool2d(2)))
# conv block 2
network.add_layer(MLX(nn.Conv2d(in_channels=96, out_channels=256, kernel_size=3)))
network.add_layer(Activation(leaky_relu))
network.add_layer(MLX(nn.MaxPool2d(2)))
# feed forward
network.add_layer(Flatten())
network.add_layer(Linear(1024))
network.add_layer(Activation(leaky_relu))
network.add_layer(Linear(10))

optimizer = SGD(eta=0.05, momentum=0.9, weight_decay=0.0005)
optimizer.bind_loss_fn(cross_entropy_loss)
optimizer.bind_network(network)

train(train_data, epochs=100, batch_size=1000, test_data=test_data)
# Out:
# Epoch 0: Accuracy 0.000, Average Loss 2.306519989172618
# Epoch 0: Accuracy 0.000, Average Loss 2.308740520477295
#
# Epoch 1: Accuracy 0.891, Average Loss 0.3059318423271179
# Epoch 1: Accuracy 0.946, Average Loss 0.15340841710567474
#
# Epoch 2: Accuracy 0.952, Average Loss 0.13643671609461308
# Epoch 2: Accuracy 0.971, Average Loss 0.07447215430438518
#
# Epoch 3: Accuracy 0.965, Average Loss 0.09734643884003162
# Epoch 3: Accuracy 0.980, Average Loss 0.052575701102614406
#
# Epoch 4: Accuracy 0.974, Average Loss 0.07440951534857353
# Epoch 4: Accuracy 0.985, Average Loss 0.041829207167029384
#
# Epoch 5: Accuracy 0.978, Average Loss 0.06605891305953264
# Epoch 5: Accuracy 0.987, Average Loss 0.03480739276856184
#
# Epoch 6: Accuracy 0.981, Average Loss 0.056110131368041036
# Epoch 6: Accuracy 0.990, Average Loss 0.03007485824637115
#
# Epoch 7: Accuracy 0.983, Average Loss 0.04995308496678869
# Epoch 7: Accuracy 0.989, Average Loss 0.028662107791751622
#
# Epoch 8: Accuracy 0.984, Average Loss 0.04541491819545627
# Epoch 8: Accuracy 0.990, Average Loss 0.02694023372605443
#
# Epoch 9: Accuracy 0.986, Average Loss 0.04024736893673738
# Epoch 9: Accuracy 0.991, Average Loss 0.024238625634461643
#
# Epoch 10: Accuracy 0.988, Average Loss 0.03572168331593275
# Epoch 10: Accuracy 0.992, Average Loss 0.021704527270048856
#
# Epoch 11: Accuracy 0.988, Average Loss 0.035301328140000504
# Epoch 11: Accuracy 0.992, Average Loss 0.022278283769264818
#
# Epoch 12: Accuracy 0.989, Average Loss 0.03297703862190247
# Epoch 12: Accuracy 0.992, Average Loss 0.021490429854020478
#
# Epoch 13: Accuracy 0.989, Average Loss 0.032707314503689605
# Epoch 13: Accuracy 0.992, Average Loss 0.021396792912855744
#
# Epoch 14: Accuracy 0.990, Average Loss 0.029576239020874102
# Epoch 14: Accuracy 0.993, Average Loss 0.01870493623428047
#
# Epoch 15: Accuracy 0.990, Average Loss 0.02877200689787666
# Epoch 15: Accuracy 0.993, Average Loss 0.01872881061863154
#
# Epoch 16: Accuracy 0.991, Average Loss 0.027835566209008296
# Epoch 16: Accuracy 0.994, Average Loss 0.01775005543604493
#
# Epoch 17: Accuracy 0.991, Average Loss 0.026159437342236438
# Epoch 17: Accuracy 0.994, Average Loss 0.016124650568235664
#
# Epoch 18: Accuracy 0.992, Average Loss 0.025061772375678023
# Epoch 18: Accuracy 0.993, Average Loss 0.017508697439916433
#
# Epoch 19: Accuracy 0.991, Average Loss 0.025803234645475945
# Epoch 19: Accuracy 0.994, Average Loss 0.019280216097831725
#
# Epoch 20: Accuracy 0.992, Average Loss 0.02465007429321607
# Epoch 20: Accuracy 0.994, Average Loss 0.016675618127919734
#
# Epoch 21: Accuracy 0.992, Average Loss 0.022186477715149523
# Epoch 21: Accuracy 0.995, Average Loss 0.016452642041258514
#
# Epoch 22: Accuracy 0.992, Average Loss 0.022539722997074327
# Epoch 22: Accuracy 0.993, Average Loss 0.016842795885168016
#
# Epoch 23: Accuracy 0.992, Average Loss 0.022246966883540154
# Epoch 23: Accuracy 0.994, Average Loss 0.015405934979207813
#
# Epoch 24: Accuracy 0.994, Average Loss 0.020011366057830552
# Epoch 24: Accuracy 0.995, Average Loss 0.015380154736340046
#
# Epoch 25: Accuracy 0.993, Average Loss 0.02125740605406463
# Epoch 25: Accuracy 0.994, Average Loss 0.015697957726661115
#
# Epoch 26: Accuracy 0.994, Average Loss 0.01929148146106551
# Epoch 26: Accuracy 0.995, Average Loss 0.014484605914913119
#
# Epoch 27: Accuracy 0.994, Average Loss 0.016409140871837737
# Epoch 27: Accuracy 0.995, Average Loss 0.014584413589909672
#
# Epoch 28: Accuracy 0.994, Average Loss 0.017397898870209854
# Epoch 28: Accuracy 0.994, Average Loss 0.015485365083441139
#
# Epoch 29: Accuracy 0.995, Average Loss 0.016276959865354
# Epoch 29: Accuracy 0.994, Average Loss 0.014331917162053287
#
# Epoch 30: Accuracy 0.995, Average Loss 0.015543310452873509
# Epoch 30: Accuracy 0.996, Average Loss 0.01322594532975927
#
# Epoch 31: Accuracy 0.995, Average Loss 0.013893298090746005
# Epoch 31: Accuracy 0.995, Average Loss 0.014126745681278408
#
# Epoch 32: Accuracy 0.995, Average Loss 0.01422140976258864
# Epoch 32: Accuracy 0.994, Average Loss 0.01490290478686802
#
# Epoch 33: Accuracy 0.995, Average Loss 0.014384378438505034
# Epoch 33: Accuracy 0.995, Average Loss 0.014630292990477755
#
# Epoch 34: Accuracy 0.996, Average Loss 0.013666647168186804
# Epoch 34: Accuracy 0.994, Average Loss 0.015176617458928376
#
# Epoch 35: Accuracy 0.996, Average Loss 0.012975585988412301
# Epoch 35: Accuracy 0.995, Average Loss 0.014828688022680581
#
# Epoch 36: Accuracy 0.996, Average Loss 0.01197638331990068
# Epoch 36: Accuracy 0.994, Average Loss 0.015146215038839728
#
# Epoch 37: Accuracy 0.996, Average Loss 0.012626865521694224
# Epoch 37: Accuracy 0.995, Average Loss 0.014185933559201658
#
# Epoch 38: Accuracy 0.996, Average Loss 0.011259626760147513
# Epoch 38: Accuracy 0.995, Average Loss 0.012537078320747241
#
# Epoch 39: Accuracy 0.996, Average Loss 0.012297693158810337
# Epoch 39: Accuracy 0.994, Average Loss 0.014374206156935543
#
# Epoch 40: Accuracy 0.996, Average Loss 0.011446117093631377
# Epoch 40: Accuracy 0.995, Average Loss 0.014395534241339191
#
# Epoch 41: Accuracy 0.996, Average Loss 0.01110177740920335
# Epoch 41: Accuracy 0.994, Average Loss 0.014282327488763258
#
# Epoch 42: Accuracy 0.996, Average Loss 0.011675133951939642
# Epoch 42: Accuracy 0.995, Average Loss 0.01404538912465796
#
# Epoch 43: Accuracy 0.997, Average Loss 0.010733312903903424
# Epoch 43: Accuracy 0.995, Average Loss 0.014666479791048914
#
# Epoch 44: Accuracy 0.997, Average Loss 0.009531776486740758
# Epoch 44: Accuracy 0.995, Average Loss 0.013062053383328021
#
# Epoch 45: Accuracy 0.996, Average Loss 0.01116622427944094
# Epoch 45: Accuracy 0.994, Average Loss 0.015449775714660063
#
# Epoch 46: Accuracy 0.996, Average Loss 0.010054332949221135
# Epoch 46: Accuracy 0.995, Average Loss 0.014032257319195196
#
# Epoch 47: Accuracy 0.996, Average Loss 0.010447636184593042
# Epoch 47: Accuracy 0.994, Average Loss 0.014494611573172732
#
# Epoch 48: Accuracy 0.997, Average Loss 0.009959472386011232
# Epoch 48: Accuracy 0.994, Average Loss 0.01542422904749401
#
# Epoch 49: Accuracy 0.997, Average Loss 0.008971283002756536
# Epoch 49: Accuracy 0.995, Average Loss 0.013534042268292978
#
# Epoch 50: Accuracy 0.997, Average Loss 0.008793878726040323
# Epoch 50: Accuracy 0.994, Average Loss 0.015000658866483718
#
# Epoch 51: Accuracy 0.998, Average Loss 0.008153317325438062
# Epoch 51: Accuracy 0.995, Average Loss 0.013656639814144
#
# Epoch 52: Accuracy 0.997, Average Loss 0.008847701584454627
# Epoch 52: Accuracy 0.994, Average Loss 0.015088505938183516
#
# Epoch 53: Accuracy 0.997, Average Loss 0.009639760915888473
# Epoch 53: Accuracy 0.993, Average Loss 0.01601006267883349
#
# Epoch 54: Accuracy 0.997, Average Loss 0.00872718963267592
# Epoch 54: Accuracy 0.995, Average Loss 0.013756293235928752
#
# Epoch 55: Accuracy 0.997, Average Loss 0.009719781042076648
# Epoch 55: Accuracy 0.994, Average Loss 0.01557048670365475
#
# Epoch 56: Accuracy 0.998, Average Loss 0.008207497012335807
# Epoch 56: Accuracy 0.995, Average Loss 0.014402736560441554
#
# Epoch 57: Accuracy 0.998, Average Loss 0.007479227664104352
# Epoch 57: Accuracy 0.994, Average Loss 0.01459601822134573
#
# Epoch 58: Accuracy 0.997, Average Loss 0.007721818087156862
# Epoch 58: Accuracy 0.994, Average Loss 0.015710347052663564
#
# Epoch 59: Accuracy 0.997, Average Loss 0.008554774584869545
# Epoch 59: Accuracy 0.994, Average Loss 0.015852733235806226
#
# Epoch 60: Accuracy 0.998, Average Loss 0.007189917583794643
# Epoch 60: Accuracy 0.994, Average Loss 0.015318579933955334
#
# Epoch 61: Accuracy 0.998, Average Loss 0.006718458563166981
# Epoch 61: Accuracy 0.994, Average Loss 0.014677604442113079
#
# Epoch 62: Accuracy 0.998, Average Loss 0.00696113557399561
# Epoch 62: Accuracy 0.995, Average Loss 0.014661520833033136
#
# Epoch 63: Accuracy 0.998, Average Loss 0.006695744063472375
# Epoch 63: Accuracy 0.994, Average Loss 0.015712323656771332
#
# Epoch 64: Accuracy 0.998, Average Loss 0.0066850873311826335
# Epoch 64: Accuracy 0.994, Average Loss 0.01712764970725402
#
# Epoch 65: Accuracy 0.998, Average Loss 0.0065166717822042605
# Epoch 65: Accuracy 0.994, Average Loss 0.014825202853535302
#
# Epoch 66: Accuracy 0.997, Average Loss 0.007969650187684843
# Epoch 66: Accuracy 0.994, Average Loss 0.016929860587697475
#
# Epoch 67: Accuracy 0.998, Average Loss 0.006350222369655966
# Epoch 67: Accuracy 0.993, Average Loss 0.01752204277436249
#
# Epoch 68: Accuracy 0.997, Average Loss 0.008060175459831953
# Epoch 68: Accuracy 0.993, Average Loss 0.018617054366040976
#
# Epoch 69: Accuracy 0.998, Average Loss 0.006173955123328293
# Epoch 69: Accuracy 0.994, Average Loss 0.01554131010780111
#
# Epoch 70: Accuracy 0.998, Average Loss 0.00669743482527944
# Epoch 70: Accuracy 0.993, Average Loss 0.01674746726639569
#
# Epoch 71: Accuracy 0.998, Average Loss 0.006211415798558543
# Epoch 71: Accuracy 0.994, Average Loss 0.01692682080902159
#
# Epoch 72: Accuracy 0.998, Average Loss 0.006612245105983069
# Epoch 72: Accuracy 0.993, Average Loss 0.017849691479932518
#
# Epoch 73: Accuracy 0.998, Average Loss 0.005904999495639155
# Epoch 73: Accuracy 0.993, Average Loss 0.017383167424122804
#
# Epoch 74: Accuracy 0.998, Average Loss 0.0054608182205508156
# Epoch 74: Accuracy 0.994, Average Loss 0.014895758032798767
#
# Epoch 75: Accuracy 0.998, Average Loss 0.0066310490326335035
# Epoch 75: Accuracy 0.994, Average Loss 0.01811559702910017
#
# Epoch 76: Accuracy 0.998, Average Loss 0.005829709867248312
# Epoch 76: Accuracy 0.994, Average Loss 0.017093742231372742
#
# Epoch 77: Accuracy 0.998, Average Loss 0.0069299548418105894
# Epoch 77: Accuracy 0.993, Average Loss 0.01647305396036245
#
# Epoch 78: Accuracy 0.998, Average Loss 0.005101189149233202
# Epoch 78: Accuracy 0.994, Average Loss 0.015944584889803083
#
# Epoch 79: Accuracy 0.998, Average Loss 0.005643563339253888
# Epoch 79: Accuracy 0.994, Average Loss 0.01761719377245754
#
# Epoch 80: Accuracy 0.998, Average Loss 0.005558740590155746
# Epoch 80: Accuracy 0.993, Average Loss 0.018573771184310316
#
# Epoch 81: Accuracy 0.998, Average Loss 0.0054351835938481
# Epoch 81: Accuracy 0.994, Average Loss 0.016776296522584742
#
# Epoch 82: Accuracy 0.998, Average Loss 0.006630958133609965
# Epoch 82: Accuracy 0.994, Average Loss 0.018060532707022504
#
# Epoch 83: Accuracy 0.998, Average Loss 0.0056052206782624125
# Epoch 83: Accuracy 0.993, Average Loss 0.016698580351658165
#
# Epoch 84: Accuracy 0.998, Average Loss 0.005262613637993733
# Epoch 84: Accuracy 0.993, Average Loss 0.018139113835059107
#
# Epoch 85: Accuracy 0.999, Average Loss 0.004631924080119158
# Epoch 85: Accuracy 0.994, Average Loss 0.017358188086654992
#
# Epoch 86: Accuracy 0.998, Average Loss 0.00548468127187031
# Epoch 86: Accuracy 0.993, Average Loss 0.018545316951349377
#
# Epoch 87: Accuracy 0.999, Average Loss 0.004409340373240411
# Epoch 87: Accuracy 0.993, Average Loss 0.018413298903033136
#
# Epoch 88: Accuracy 0.998, Average Loss 0.0070658233695818735
# Epoch 88: Accuracy 0.993, Average Loss 0.021128524979576468
#
# Epoch 89: Accuracy 0.998, Average Loss 0.00576649397262372
# Epoch 89: Accuracy 0.993, Average Loss 0.01898013356840238
#
# Epoch 90: Accuracy 0.998, Average Loss 0.0055248667379297935
# Epoch 90: Accuracy 0.994, Average Loss 0.019091902300715446
#
# Epoch 91: Accuracy 0.999, Average Loss 0.004279215802671388
# Epoch 91: Accuracy 0.994, Average Loss 0.017383639462059362
#
# Epoch 92: Accuracy 0.998, Average Loss 0.005544078293799733
# Epoch 92: Accuracy 0.994, Average Loss 0.020270293205976488
#
# Epoch 93: Accuracy 0.998, Average Loss 0.005222034667773793
# Epoch 93: Accuracy 0.993, Average Loss 0.018137883010786025
#
# Epoch 94: Accuracy 0.998, Average Loss 0.004880680396066358
# Epoch 94: Accuracy 0.993, Average Loss 0.01842239445541054
#
# Epoch 95: Accuracy 0.999, Average Loss 0.004194036197926228
# Epoch 95: Accuracy 0.994, Average Loss 0.01923529723426327
#
# Epoch 96: Accuracy 0.998, Average Loss 0.004767796342882017
# Epoch 96: Accuracy 0.993, Average Loss 0.01859394331695512
#
# Epoch 97: Accuracy 0.998, Average Loss 0.0047470349236391485
# Epoch 97: Accuracy 0.993, Average Loss 0.020930730644613503
#
# Epoch 98: Accuracy 0.999, Average Loss 0.004456410397930692
# Epoch 98: Accuracy 0.994, Average Loss 0.018786388065200298
#
# Epoch 99: Accuracy 0.999, Average Loss 0.0044893939649531
# Epoch 99: Accuracy 0.993, Average Loss 0.02114648596616462
#
# Epoch 100: Accuracy 0.999, Average Loss 0.004455992891841258
# Epoch 100: Accuracy 0.993, Average Loss 0.0199293430254329
#
# Accuracy 0.993, Average Loss 0.0199293430254329

# %%
kernels = network.layers[0].params['weight']
kernel = np.array(kernels[50])
print("Kernel Shape:", kernels.shape)
print("Example:", kernel)

def normalize(kernel):
    kernel -= np.min(kernel)
    kernel /= np.max(kernel)
    return 255 * kernel.reshape(kernel.shape[0], kernel.shape[1])

kernel_img = Image.fromarray(normalize(kernel))
plt.imshow(kernel_img)
# Out:
# Kernel Shape: (96, 7, 7, 1)
# Example: [[[ 0.05624962]
#   [-0.00557109]
#   [ 0.13481644]
#   [-0.09140311]
#   [ 0.12092379]
#   [ 0.16331847]
#   [-0.1168772 ]]
#
#  [[ 0.03823464]
#   [ 0.15053357]
#   [ 0.13044204]
#   [-0.12364443]
#   [-0.0171165 ]
#   [-0.03200873]
#   [-0.13346182]]
#
#  [[-0.1525908 ]
#   [ 0.11875655]
#   [-0.13612011]
#   [-0.24855532]
#   [-0.21677968]
#   [-0.05776845]
#   [-0.14250077]]
#
#  [[-0.16142094]
#   [ 0.10356681]
#   [-0.0188626 ]
#   [ 0.01450184]
#   [ 0.2522075 ]
#   [ 0.2356243 ]
#   [ 0.2526863 ]]
#
#  [[ 0.09879256]
#   [ 0.19510838]
#   [ 0.18035856]
#   [ 0.24804428]
#   [ 0.17810197]
#   [ 0.12897618]
#   [ 0.21792676]]
#
#  [[ 0.08621721]
#   [-0.01003623]
#   [ 0.02897117]
#   [-0.1751792 ]
#   [-0.21213467]
#   [-0.1807253 ]
#   [-0.07226743]]
#
#  [[-0.00925271]
#   [-0.13389124]
#   [-0.17088744]
#   [-0.01066316]
#   [-0.03044   ]
#   [-0.13621776]
#   [-0.20579815]]]

# %%
def viz_kernels(kernels, rows=24, cols=4, figsize=(10, 60)):
    fig, axes = plt.subplots(rows, cols, figsize=figsize, num="Sample Predictions")
    axes = axes.reshape(-1)  # flatten

    def normalize_kernels(kernels):
        kernels = np.array(kernels.reshape(kernels.shape[0], kernels.shape[1], kernels.shape[2]))

        kernels = kernels - np.min(kernels)
        kernels = kernels / np.max(kernels)
        kernels = np.square(kernels)

        print("Mins", np.min(kernels))
        print("Maxs", np.max(kernels))

        return kernels

    kernels = normalize_kernels(kernels)

    def normalize(kernel):
        return 255 * kernel

    def imagize(kernel):
        return Image.fromarray(normalize(kernel))

    for j, kernel in enumerate(kernels):
        kernel_img = imagize(kernel)
        axes[j].imshow(kernel_img)
        axes[j].set_title(f"Kernel {j}")
        axes[j].axis('off')
        plt.subplots_adjust(wspace=1)

    plt.show()

viz_kernels(network.layers[0].params['weight'])
# Out:
# Mins 0.0
# Maxs 1.0
